# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("pokemon_data.csv",delimiter=",")
#pd.read_xlsx()
#pd.read_csv("blabla.txt")

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.head(5) #untuk ambil 'n' data teratas
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.tail(5) #untuk ambil 'n' data terbawah
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df.columns #untuk menunjukkan isi kolom ada apa saja
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df["Name"].head(5)
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
df["Attack"].head(5)
# Out:
# 0     49
# 1     62
# 2     82
# 3    100
# 4     52
# Name: Attack, dtype: int64

# %%
df["Attack"].mean()
# Out:
# 79.00125

# %%
df["Attack"].max()
# Out:
# 190

# %%
df["Attack"].min()
# Out:
# 5

# %%
c=df["Attack"].tolist()

# %%
c.sort()

# %%
df.iloc[0:3,:3]
# Out:
#    #       Name Type 1
# 0  1  Bulbasaur  Grass
# 1  2    Ivysaur  Grass
# 2  3   Venusaur  Grass

# %%
#for index,row in df.iterrows():
#    print (index,row['Name'],"\t\t\t",row['Attack'])

# %%
df.loc[df["Type 1"]=="Grass"][["Name","Defense"]]
# Out:
#                       Name  Defense
# 0                Bulbasaur       49
# 1                  Ivysaur       63
# 2                 Venusaur       83
# 3    VenusaurMega Venusaur      123
# 48                  Oddish       55
# ..                     ...      ...
# 718                Chespin       65
# 719              Quilladin       95
# 720             Chesnaught      122
# 740                 Skiddo       48
# 741                 Gogoat       62
#
# [70 rows x 2 columns]

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values("Name")
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(["Type 1","HP"], ascending=[0,1]) 
#Type 1 ascending nya False makanya diurutin dari huruf paling bawah, HP ascending nya True jadi urutan HP mulai dari paling rendah
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
# 97    90                 Shellder  Water       NaN  30      65      100
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# ..   ...                      ...    ...       ...  ..     ...      ...
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# 734  666                 Vivillon    Bug    Flying  80      52       50
# 698  637                Volcarona    Bug      Fire  85      60       65
# 520  469                  Yanmega    Bug    Flying  86      76       86
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df["kolombaru"]=df["Attack"]+df["Defense"] #cara nambah kolom baru

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  kolombaru
# 0         65       65     45           1      False         98
# ...

# %%
#df=df.drop(columns="kolombaru")

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  kolombaru
# 0         65       65     45           1      False         98
# ...

# %%
cols=list(df.columns)

# %%
cols
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'kolombaru']

# %%
df=df[cols[:2]+[cols[-1]]+cols[2:12]]

# %%
df.head(5)
# Out:
#    #                   Name  kolombaru Type 1  Type 2  HP  Attack  Defense  \
# 0  1              Bulbasaur         98  Grass  Poison  45      49       49
# 1  2                Ivysaur        125  Grass  Poison  60      62       63
# 2  3               Venusaur        165  Grass  Poison  80      82       83
# 3  3  VenusaurMega Venusaur        223  Grass  Poison  80     100      123
# 4  4             Charmander         95   Fire     NaN  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.to_csv("databaru.csv",index=False)

# %%
#kalau mau filter data bisa pake :
new_df=df.loc[(df["Type 1"]=="Grass")&(df["Type 2"]=="Poison")&(df["HP"]>70)] #biasanya di python pake and tapi di pandas pake nya &
new_df=new_df.reset_index(drop=True) #reset_index buat bikin indeks nya di tulis ulang, drop buat apus indeks lama

# %%
new_df
# Out:
#      #                   Name  kolombaru Type 1  Type 2   HP  Attack  Defense  \
# 0    3               Venusaur        165  Grass  Poison   80      82       83
# 1    3  VenusaurMega Venusaur        223  Grass  Poison   80     100      123
# 2   45              Vileplume        165  Grass  Poison   75      80       85
# 3   71             Victreebel        170  Grass  Poison   80     105       65
# 4  591              Amoonguss        155  Grass  Poison  114      85       70
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0      100      100     80           1      False
# 1      122      120     80           1      False
# 2      110       90     50           1      False
# 3      100       70     70           1      False
# 4       85       80     30           5      False

# %%
new_df=new_df.loc[~new_df["Name"].str.contains("Mega")]
new_df
# Out:
#      #        Name  kolombaru Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0    3    Venusaur        165  Grass  Poison   80      82       83      100
# 2   45   Vileplume        165  Grass  Poison   75      80       85      110
# 3   71  Victreebel        170  Grass  Poison   80     105       65      100
# 4  591   Amoonguss        155  Grass  Poison  114      85       70       85
#
#    Sp. Def  Speed  Generation  Legendary
# 0      100     80           1      False
# 2       90     50           1      False
# 3       70     70           1      False
# 4       80     30           5      False
